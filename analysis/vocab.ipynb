# %% [markdown]
# Analyse the vocabulary.

# %%
import json
from collections import Counter
from matplotlib import pyplot as plt

# %%
vocab = json.load(open('../data/vocab/repo_vocab.json'))

# %%
len(vocab)
# Out:
# 8892623

# %%
vocab_cnt = Counter(vocab.values())
len_cnt = Counter([word.count(' ')+1 for word in vocab])
len_cnt.most_common()
# Out:
# [(4, 4127442), (3, 3267927), (2, 1371679), (1, 125575)]

# %%
total = [4127442, 3267927, 1371679, 125575]
for i in total:
    print(i/sum(total))
# Out:
# 0.4641422446448028
# 0.367487410632386
# 0.1542490893856627
# 0.014121255337148555

# %%
plt.pie(len_cnt.values(), labels=len_cnt.keys())
plt.title('Number of words per entry.')
plt.show()

# %%
print(f'There are {len(vocab)} words in the vocabulary.')
print(f'{round(vocab_cnt[1]/len(vocab), 2)} of the words in the vocabulary only occur once in the repositories.')
# Out:
# There are 8892623 words in the vocabulary.
# 0.87 of the words in the vocabulary only occur once in the repositories.

# %%
x = [str(i) for i in range(1, 4)] + ['4+']
y = [i[1] for i in vocab_cnt.most_common(3)] + [sum([i[1] for i in vocab_cnt.most_common()][3:])]
plt.pie(y, labels=x)
plt.title('Frequency of each entry.')
plt.show()

# %% [markdown]
# Now we will look at the words that occur only once.

# %%
once = [k for k, v in vocab.items() if v == 1]
once[:10]
# Out:
# ['good &',
#  '& distribution',
#  'century face',
#  'face three',
#  ': mitigate',
#  'mitigate inequality',
#  'unregulated release',
#  'and underfinanced',
#  'underfinanced infrastructure',
#  'of mismanage']

# %%
len_cnt_once = Counter([word.count(' ')+1 for word in once])
len_cnt_once.most_common()
# Out:
# [(4, 3860977), (3, 2805062), (2, 978774), (1, 75436)]

# %%
plt.pie(len_cnt_once.values(), labels=len_cnt_once.keys())
plt.title('Number of words per entry that occurs once.')
plt.show()

# %%
for i in range(1, len(len_cnt)+1):
    print(f'{len_cnt_once[i]} out of {len_cnt[i]} entries with {i} words occur only once - {round(len_cnt_once[i]/len_cnt[i], 2)}.')
# Out:
# 75436 out of 125575 entries with 1 words occur only once - 0.6.
# 978774 out of 1371679 entries with 2 words occur only once - 0.71.
# 2805062 out of 3267927 entries with 3 words occur only once - 0.86.
# 3860977 out of 4127442 entries with 4 words occur only once - 0.94.

# %% [markdown]
# Now we will look at words that occur very often.

# %%
n_docs = 29336  # no. of docs, as seen in repo_vocab_1.log
often = [k for k, v in vocab.items() if v > 1000]
print(f'{len(often)} entries occur in more than 4 % of the documents.')
# Out:
# 733 entries occur in more than 4 % of the documents.

# %%
print(often[:10])
# Out:
# ['common', 'good', 'distribution', 'policy', 'three', 'key', 'challenge', 'high', 'level', 'global']

# %%
len_cnt_often = Counter([word.count(' ')+1 for word in often])
len_cnt_often.most_common()
# Out:
# [(1, 487), (2, 221), (3, 24), (4, 1)]

# %%
[k for k in often if k.count(' ') > 1]
# Out:
# ['as well as',
#  'part of the',
#  'in term of',
#  'one of the',
#  'the presence of',
#  'in order to',
#  'the influence of',
#  'with respect to',
#  'the role of',
#  'due to the',
#  'be use to',
#  'the development of',
#  'base on the',
#  'be base on',
#  'show that the',
#  'in this thesis',
#  'the impact of',
#  'the use of',
#  'the result of',
#  'well as the',
#  'as well as the',
#  'be able to',
#  'depend on the',
#  'the effect of',
#  'we show that']

# %%
vocab['as well as the']
# Out:
# 1132

# %% [markdown]
# Now we look at entries that comprise four words and occur often.

# %%
four = [k for k, v in vocab.items() if v > 1000 and k.count(' ') == 3]

# %%
len(four), four[:3]
# Out:
# (1, ['as well as the'])

# %% [markdown]
# Only one of the entries that occur more than 1K times comprises four words.
